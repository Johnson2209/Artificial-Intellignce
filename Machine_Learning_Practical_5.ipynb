# %% [markdown]
# # LE-NET DEEP NETWORK- TRAFFIC SIGN CLASSIFICATION

# %% [markdown]
# ### The goal is to help self-driven cars make decisions. The cars need to be able to identify objects so that it can know when to start, or how well to run

# %%
## Code to classify traffic signs using Le-Net architecture in Keras

# %% [markdown]
# # Section 1: Problem Statement
#
# * In this case study, you have been provided with images of traffic signs and the goal is to train a Deep Network to classify them.
#
# * The dataset contains 43 different classes of images.
#
# * Examples of words on the traffic signs/images include: "No passing", "Speed Limit (100km/hr)", "Road narrow on the right". etc
#
# * The network used is called Le-Net that was presented by Yan LeCun: "Gradient Based Learning Applied to Document Recognition, 1998"

# %% [markdown]
# - Classes/labels are as listed below:
#
#     - ( 0, b'Speed limit (20km/h)') ( 1, b'Speed limit (30km/h)')
#     - ( 2, b'Speed limit (50km/h)') ( 3, b'Speed limit (60km/h)')
#     - ( 4, b'Speed limit (70km/h)') ( 5, b'Speed limit (80km/h)')
#     - ( 6, b'End of speed limit (80km/h)') ( 7, b'Speed limit (100km/h)')
#     - ( 8, b'Speed limit (120km/h)') ( 9, b'No passing')
#     - (10, b'No passing for vehicles over 3.5 metric tons')
#     - (11, b'Right-of-way at the next intersection') (12, b'Priority road')
#     - (13, b'Yield') (14, b'Stop') (15, b'No vehicles')
#     - (16, b'Vehicles over 3.5 metric tons prohibited') (17, b'No entry')
#     - (18, b'General caution') (19, b'Dangerous curve to the left')
#     - (20, b'Dangerous curve to the right') (21, b'Double curve')
#     - (22, b'Bumpy road') (23, b'Slippery road')
#     - (24, b'Road narrows on the right') (25, b'Road work')
#     - (26, b'Traffic signals') (27, b'Pedestrians') (28, b'Children crossing')
#     - (29, b'Bicycles crossing') (30, b'Beware of ice/snow')
#     - (31, b'Wild animals crossing')
#     - (32, b'End of all speed and passing limits') (33, b'Turn right ahead')
#     - (34, b'Turn left ahead') (35, b'Ahead only') (36, b'Go straight or right')
#     - (37, b'Go straight or left') (38, b'Keep right') (39, b'Keep left')
#     - (40, b'Roundabout mandatory') (41, b'End of no passing')
#     - (42, b'End of no passing by vehicles over 3.5 metric tons')
#
# - The network used is called Le-Net that was presented by Yann LeCun
# http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf

# %% [markdown]
# # Section 2: Import Libraries and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
# The pickle module implements binary protocols for serializing and de-serializing a Python object structure.
   
with open("train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
# This shows that the image is 32 $\times$ 32 \times 3 pixels. The '3' indicates the image is coloured(RGB)
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %%
y_validation.shape
# Out:
# (4410,)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
y_test.shape
# Out:
# (12630,)

# %% [markdown]
# # Section 2: Image Exploration

# %%
i = 6555
plt.imshow(X_train[i]) # Show images are not shuffled
y_train[i]
# Out:
# 3

# %%
i = 2500
plt.imshow(X_validation[i]) # Show images are not shuffled
y_validation[i]
# Out:
# 35

# %%
i = 400
plt.imshow(X_test[i]) # Show images are not shuffled
y_test[i]
# Out:
# 38

# %% [markdown]
# # Section 3: Data Preparation

# %%
## Shuffle the dataset (to avoid overfitting)
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
#we are changing the images from "coloured" to "gray" by averaging the pixels
X_train_gray = np.sum(X_train/3, axis=3, keepdims=True)
X_test_gray  = np.sum(X_test/3, axis=3, keepdims=True)
X_validation_gray  = np.sum(X_validation/3, axis=3, keepdims=True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
#Data Normalization
X_train_gray_norm = (X_train_gray - 128)/128 
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
i = 610
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])

# %%
i = 610
plt.imshow(X_test_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_test_gray_norm[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_test[i])

# %% [markdown]
# # Section 4: Model Training

# %%
i = 610
plt.imshow(X_validation_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_validation_gray_norm[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_validation[i])

# %% [markdown]
# # Section 4: Model Training

# %% [markdown]
# The model consists of the following layers:
#
# - STEP 1: THE FIRST CONVOLUTIONAL LAYER #1
#     - Input = 32x32x1
#     - Output = 28x28x6
#     - Output = (Input-filter+1)/Stride* => (32-5+1)/1=28
#     - Used a 5x5 Filter with input depth of 3 and output depth of 6
#     - Apply a RELU Activation function to the output
#     - pooling for input, Input = 28x28x6 and Output = 14x14x6
#
#
#     * Stride is the amount by which the kernel is shifted when the kernel is passed over the image.
#
# - STEP 2: THE SECOND CONVOLUTIONAL LAYER #2
#     - Input = 14x14x6
#     - Output = 10x10x16
#     - Layer 2: Convolutional layer with Output = 10x10x16
#     - Output = (Input-filter+1)/strides => 10 = 14-5+1/1
#     - Apply a RELU Activation function to the output
#     - Pooling with Input = 10x10x16 and Output = 5x5x16
#
# - STEP 3: FLATTENING THE NETWORK
#     - Flatten the network with Input = 5x5x16 and Output = 400
#
# - STEP 4: FULLY CONNECTED LAYER
#     - Layer 3: Fully Connected layer with Input = 400 and Output = 120
#     - Apply a RELU Activation function to the output
#
# - STEP 5: ANOTHER FULLY CONNECTED LAYER
#     - Layer 4: Fully Connected Layer with Input = 120 and Output = 84
#     - Apply a RELU Activation function to the output
#
# - STEP 6: FULLY CONNECTED LAYER
#     - Layer 5: Fully Connected layer with Input = 84 and Output = 43

# %%
# !pip install keras
import keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.6.0)

# %%
# !pip install sklearn
import sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.19.5)

# %%
# Import train_test_split from scikit library

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from keras.callbacks import TensorBoard

from sklearn.model_selection import train_test_split

# %%
image_shape = X_train_gray[i].shape

# %%
cnn_model = Sequential()

cnn_model.add(Conv2D(filters=6, kernel_size=(5, 5), activation='relu', input_shape=(32,32,1)))
cnn_model.add(AveragePooling2D())

cnn_model.add(Conv2D(filters=16, kernel_size=(5, 5), activation='relu'))
cnn_model.add(AveragePooling2D())

cnn_model.add(Flatten())

cnn_model.add(Dense(units=120, activation='relu'))

cnn_model.add(Dense(units=84, activation='relu'))

cnn_model.add(Dense(units=43, activation = 'softmax'))

# %%
cnn_model.compile(loss ='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.001),metrics =['accuracy'])

# %%
history = cnn_model.fit(X_train_gray_norm,
                        y_train,
                        batch_size=500,
                        epochs=50,
                        verbose=1,
                        validation_data = (X_validation_gray_norm,y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 15s 208ms/step - loss: 3.1663 - accuracy: 0.1845 - val_loss: 2.6084 - val_accuracy: 0.3093
# Epoch 2/50
# 70/70 [==============================] - 14s 202ms/step - loss: 1.6353 - accuracy: 0.5487 - val_loss: 1.2970 - val_accuracy: 0.6195
# Epoch 3/50
# 70/70 [==============================] - 14s 205ms/step - loss: 0.8903 - accuracy: 0.7442 - val_loss: 0.9299 - val_accuracy: 0.7163
# Epoch 4/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.6294 - accuracy: 0.8244 - val_loss: 0.7932 - val_accuracy: 0.7703
# Epoch 5/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.4996 - accuracy: 0.8638 - val_loss: 0.7323 - val_accuracy: 0.7882
# Epoch 6/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.4058 - accuracy: 0.8914 - val_loss: 0.6642 - val_accuracy: 0.8020
# Epoch 7/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.3429 - accuracy: 0.9098 - val_loss: 0.6468 - val_accuracy: 0.8195
# Epoch 8/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.3009 - accuracy: 0.9213 - val_loss: 0.6225 - val_accuracy: 0.8218
# Epoch 9/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.2597 - accuracy: 0.9323 - val_loss: 0.6161 - val_accuracy: 0.8281
# Epoch 10/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.2306 - accuracy: 0.9411 - val_loss: 0.5793 - val_accuracy: 0.8385
# Epoch 11/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.2067 - accuracy: 0.9480 - val_loss: 0.5814 - val_accuracy: 0.8444
# Epoch 12/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.1850 - accuracy: 0.9526 - val_loss: 0.5534 - val_accuracy: 0.8544
# Epoch 13/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.1675 - accuracy: 0.9578 - val_loss: 0.5422 - val_accuracy: 0.8612
# Epoch 14/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.1516 - accuracy: 0.9622 - val_loss: 0.5497 - val_accuracy: 0.8628
# Epoch 15/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.1378 - accuracy: 0.9663 - val_loss: 0.5610 - val_accuracy: 0.8574
# Epoch 16/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.1257 - accuracy: 0.9690 - val_loss: 0.5586 - val_accuracy: 0.8667
# Epoch 17/50
# 70/70 [==============================] - 15s 210ms/step - loss: 0.1158 - accuracy: 0.9713 - val_loss: 0.5663 - val_accuracy: 0.8587
# Epoch 18/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.1032 - accuracy: 0.9742 - val_loss: 0.5247 - val_accuracy: 0.8719
# Epoch 19/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.0989 - accuracy: 0.9759 - val_loss: 0.5424 - val_accuracy: 0.8728
# Epoch 20/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.0870 - accuracy: 0.9784 - val_loss: 0.5444 - val_accuracy: 0.8751
# Epoch 21/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.0790 - accuracy: 0.9804 - val_loss: 0.5538 - val_accuracy: 0.8737
# Epoch 22/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.0739 - accuracy: 0.9826 - val_loss: 0.5919 - val_accuracy: 0.8723
# Epoch 23/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.0676 - accuracy: 0.9834 - val_loss: 0.5663 - val_accuracy: 0.8651
# Epoch 24/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.0635 - accuracy: 0.9851 - val_loss: 0.6043 - val_accuracy: 0.8692
# Epoch 25/50
# 70/70 [==============================] - 15s 210ms/step - loss: 0.0573 - accuracy: 0.9864 - val_loss: 0.6062 - val_accuracy: 0.8735
# Epoch 26/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.0514 - accuracy: 0.9884 - val_loss: 0.5920 - val_accuracy: 0.8735
# Epoch 27/50
# 70/70 [==============================] - 15s 210ms/step - loss: 0.0489 - accuracy: 0.9890 - val_loss: 0.5745 - val_accuracy: 0.8778
# Epoch 28/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.0441 - accuracy: 0.9901 - val_loss: 0.5956 - val_accuracy: 0.8757
# Epoch 29/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.0435 - accuracy: 0.9898 - val_loss: 0.7012 - val_accuracy: 0.8746
# Epoch 30/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.0382 - accuracy: 0.9913 - val_loss: 0.6730 - val_accuracy: 0.8726
# Epoch 31/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.0359 - accuracy: 0.9918 - val_loss: 0.6958 - val_accuracy: 0.8794
# Epoch 32/50
# 70/70 [==============================] - 15s 211ms/step - loss: 0.0384 - accuracy: 0.9904 - val_loss: 0.6472 - val_accuracy: 0.8803
# Epoch 33/50
# 70/70 [==============================] - 15s 213ms/step - loss: 0.0365 - accuracy: 0.9909 - val_loss: 0.6410 - val_accuracy: 0.8864
# Epoch 34/50
# 70/70 [==============================] - 15s 212ms/step - loss: 0.0307 - accuracy: 0.9928 - val_loss: 0.7085 - val_accuracy: 0.8814
# Epoch 35/50
# 70/70 [==============================] - 15s 211ms/step - loss: 0.0286 - accuracy: 0.9933 - val_loss: 0.6978 - val_accuracy: 0.8841
# Epoch 36/50
# 70/70 [==============================] - 15s 213ms/step - loss: 0.0262 - accuracy: 0.9939 - val_loss: 0.7637 - val_accuracy: 0.8732
# Epoch 37/50
# 70/70 [==============================] - 15s 214ms/step - loss: 0.0241 - accuracy: 0.9948 - val_loss: 0.7462 - val_accuracy: 0.8726
# Epoch 38/50
# 70/70 [==============================] - 15s 215ms/step - loss: 0.0229 - accuracy: 0.9944 - val_loss: 0.7565 - val_accuracy: 0.8744
# Epoch 39/50
# 70/70 [==============================] - 15s 214ms/step - loss: 0.0208 - accuracy: 0.9948 - val_loss: 0.7957 - val_accuracy: 0.8791
# Epoch 40/50
# 70/70 [==============================] - 15s 215ms/step - loss: 0.0222 - accuracy: 0.9951 - val_loss: 0.7802 - val_accuracy: 0.8760
# Epoch 41/50
# 70/70 [==============================] - 15s 212ms/step - loss: 0.0171 - accuracy: 0.9963 - val_loss: 0.7510 - val_accuracy: 0.8755
# Epoch 42/50
# 70/70 [==============================] - 15s 215ms/step - loss: 0.0171 - accuracy: 0.9957 - val_loss: 0.7614 - val_accuracy: 0.8751
# Epoch 43/50
# 70/70 [==============================] - 15s 216ms/step - loss: 0.0220 - accuracy: 0.9942 - val_loss: 0.8108 - val_accuracy: 0.8728
# Epoch 44/50
# 70/70 [==============================] - 15s 220ms/step - loss: 0.0329 - accuracy: 0.9901 - val_loss: 0.7144 - val_accuracy: 0.8837
# Epoch 45/50
# 70/70 [==============================] - 16s 226ms/step - loss: 0.0172 - accuracy: 0.9957 - val_loss: 0.7988 - val_accuracy: 0.8676
# Epoch 46/50
# 70/70 [==============================] - 15s 220ms/step - loss: 0.0134 - accuracy: 0.9971 - val_loss: 0.8140 - val_accuracy: 0.8780
# Epoch 47/50
# 70/70 [==============================] - 15s 220ms/step - loss: 0.0102 - accuracy: 0.9980 - val_loss: 0.8164 - val_accuracy: 0.8821
# Epoch 48/50
# 70/70 [==============================] - 15s 217ms/step - loss: 0.0097 - accuracy: 0.9983 - val_loss: 0.7971 - val_accuracy: 0.8855
# Epoch 49/50
# 70/70 [==============================] - 15s 213ms/step - loss: 0.0087 - accuracy: 0.9983 - val_loss: 0.7591 - val_accuracy: 0.8823
# Epoch 50/50
# 70/70 [==============================] - 15s 215ms/step - loss: 0.0105 - accuracy: 0.9976 - val_loss: 0.8060 - val_accuracy: 0.8796

# %% [markdown]
# # Section 5: Model Evaluation

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Accuracy : 0.8735

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#get the predictions for the test data
predicted_classes = cnn_model.predict(X_test_gray_norm)
predicted_classes = np.argmax(predicted_classes,axis=1)
#get the indices to be plotted
y_true = y_test

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25,25))
sns.heatmap(cm, annot=True)

# %%
L = 7
W = 7
fig, axes = plt.subplots(L, W, figsize = (12,12))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(X_test[i])
    axes[i].set_title("Prediction={}\n True={}".format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
